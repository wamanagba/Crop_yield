# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler

# %%
df=data = pd.read_csv('Mil_all.csv')
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']
len(vect)
# Out:
# 45

# %%
df
# Out:
#        province  year  driver.TSA  Driver.TNA  sahel_rainfall        QBO  \
# 0          Bale  2000    0.286667   -0.076667       -1.333333  -1.613333
# 1           Bam  2000    0.286667   -0.076667       -1.333333  -1.613333
# 2          Bale  2001    0.403333    0.116667       41.000000 -20.676667
# 3         Banwa  2000    0.286667   -0.076667       -1.333333  -1.613333
# 4          Bale  2002    0.376667   -0.113333      -74.666667  13.816667
# ..          ...   ...         ...         ...             ...        ...
# 760        Ziro  2016    0.473333    0.363333       64.666667   2.290000
# 761  Zoundweogo  2015    0.400000   -0.076667      -81.000000 -11.510000
# 762     Zondoma  2015    0.400000   -0.076667      -81.000000 -11.510000
# 763     Zondoma  2016    0.473333    0.363333       64.666667   2.290000
# 764  Zoundweogo  2016    0.473333    0.363333       64.666667   2.290000
#
#           NAO     gmsst        EA   AMM_sst  ...        TXx        TXn  \
# 0    0.540000  0.626667 -0.110000 -1.900000  ...  34.273820  27.480223
# 1    0.540000  0.626667 -0.110000 -1.900000  ...  37.970008  29.030460
# 2   -0.003333  0.663333  0.456667 -1.390000  ...  35.254153  27.160694
# 3    0.540000  0.626667 -0.110000 -1.900000  ...  35.126816  27.881790
# 4    0.560000  0.773333  0.106667 -3.733333  ...  35.418921  26.515894
# ..        ...       ...       ...       ...  ...        ...        ...
# 760 -0.180000  1.206667 -1.446667 -0.530000  ...  35.084163  27.285031
# 761  0.356667  0.893333 -0.386667 -4.620000  ...  36.772313  27.980089
# 762  0.356667  0.893333 -0.386667 -4.620000  ...  37.901526  27.734897
# 763 -0.180000  1.206667 -1.446667 -0.530000  ...  37.605990  27.118584
# 764 -0.180000  1.206667 -1.446667 -0.530000  ...  34.827836  27.172490
#
#      Chirts_Tmax_Temp  Chirts_Tmin_Temp  ERA5_Pressure  ERA5_wins  \
# 0           30.922271         23.199671    101164.2983   2.297034
# 1           33.315506         24.437828    101080.2082   2.486396
# 2           30.982465         23.648841    101230.8929   2.354358
# 3           31.130041         23.347214    101163.6513   2.308840
# 4           31.162913         23.854538    101202.3614   2.423180
# ..                ...               ...            ...        ...
# 760         31.304793         24.271595    101250.7688   2.213240
# 761         31.607796         24.646400    101233.8396   2.204683
# 762         32.029358         23.836421    101194.1389   2.179053
# 763         32.359881         24.183867    101190.4650   2.307139
# 764         31.491948         24.569538    101237.8495   2.249123
#
#      chirps_Prec  ERA5_soil_moisture      NDVI  Mil.rendement
# 0     758.166110            0.387494  0.161495         966.11
# 1     512.259347            0.216186  0.087916         428.00
# 2     834.762064            0.384737  0.151293         979.60
# 3     714.185174            0.325074  0.157605         956.89
# 4     728.571496            0.361794  0.126205         850.50
# ..           ...                 ...       ...            ...
# 760   994.080679            0.350803  0.187898         841.10
# 761   941.527205            0.367755  0.114412        1165.20
# 762   781.464918            0.216907  0.099424        1147.40
# 763   776.613143            0.200586  0.110635         524.50
# 764   957.519613            0.373106  0.127583        1127.60
#
# [765 rows x 38 columns]

# %%
def correlation(df,level):
    dt=df.loc[df['province'].isin([level])]
    X = dt.iloc[:, 1:38]
    #y = dt.iloc[:, 37]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI',36:'Sorgho'})
    #a= pd.DataFrame(pd.DataFrame(dt.corrwith(y, axis = 0)).iloc[:,0])

    a=pd.DataFrame(pd.DataFrame(X.corr()).iloc[:,36])
    a.columns=[level]
    return a

# %%
#c=correlation(df,'Banwa')
#c

# %%
def sort_corr(df,level):
    c=correlation(df,level)
    #c= c.sort_values(by=['Bougouriba'])
    absolute=c[level].abs()

    b=pd.DataFrame(absolute).sort_values(by=[level],ascending=False)
    df2 = pd.merge(b, c, left_index=True, right_index=True)
    return df2

# %%
sort_corr(df,'Banwa')
# Out:
#                      Banwa_x   Banwa_y
# Sorgho              1.000000  1.000000
# gmsst               0.382943 -0.382943
# QBO                 0.380832  0.380832
# chirps_Prec         0.376825 -0.376825
# TXx                 0.371726  0.371726
# R1mm                0.369657 -0.369657
# Chirts_Tmin_Temp    0.357572 -0.357572
# AMO_sst             0.353487 -0.353487
# R20mm               0.337251 -0.337251
# TNn                 0.318318 -0.318318
# EA                  0.282035  0.282035
# driver.TSA          0.272981 -0.272981
# PRCPTOT             0.265980 -0.265980
# R95pTOT             0.223916 -0.223916
# TNx                 0.211904  0.211904
# ERA5_soil_moisture  0.199415 -0.199415
# Driver.NTA          0.191270 -0.191270
# SDII                0.188529 -0.188529
# Driver.TNA          0.168537 -0.168537
# Driver.AO           0.156214 -0.156214
# year                0.155600 -0.155600
# Chirts_Tmax_Temp    0.153220  0.153220
# RX1day              0.139055  0.139055
# ERA5_wins           0.136673 -0.136673
# PDO                 0.126286 -0.126286
# AMM_sst             0.094857 -0.094857
# CDD                 0.082956  0.082956
# R10mm               0.075024 -0.075024
# TXn                 0.073267  0.073267
# R5mm                0.062898 -0.062898
# RX5day              0.059156  0.059156
# NDVI                0.047797 -0.047797
# R99pTOT             0.047199 -0.047199
# ERA5_Pressure       0.045958 -0.045958
# NAO                 0.032068  0.032068
# sahel_rainfall      0.025102 -0.025102
# CWD                 0.008061 -0.008061

# %%
def table(df,v):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        D=pd.concat([D,correlation(df,v[i])],axis = 1)
    return D

# %%
table(df,vect)
# Out:
#                         Bale     Banwa     Kossi   Mouhoun    Nayala  \
# year                0.434443 -0.310529 -0.254234 -0.204810  0.018158
# driver.TSA          0.254395 -0.158847 -0.199132 -0.108434  0.125947
# Driver.TNA          0.489528 -0.048690  0.410915  0.123915 -0.012952
# sahel_rainfall     -0.044246 -0.048900  0.170747 -0.137175  0.176630
# QBO                -0.317428  0.412701 -0.017399  0.137081 -0.361031
# NAO                -0.075286  0.375220 -0.114734  0.123121 -0.068691
# gmsst               0.399889 -0.553743 -0.373468 -0.283936  0.172129
# EA                 -0.532406 -0.113226 -0.437308 -0.254164  0.050390
# AMM_sst             0.407368  0.006233  0.478944  0.107327  0.028437
# Driver.NTA          0.521467 -0.074025  0.373212  0.110598 -0.007770
# AMO_sst             0.274374 -0.047563  0.305892  0.296913 -0.139565
# Driver.AO          -0.055992  0.256768 -0.276397  0.148876 -0.000295
# PDO                -0.236500 -0.020784 -0.052106  0.084253 -0.272469
# PRCPTOT             0.242386 -0.167937  0.117133  0.025708  0.369328
# R10mm               0.088429 -0.108925 -0.072177 -0.157270  0.367185
# R1mm                0.163213  0.401531  0.044677  0.416181  0.192304
# R20mm               0.479944 -0.218082  0.117629 -0.036914  0.620565
# R5mm                0.002856 -0.072029 -0.101879  0.326715 -0.211874
# R95pTOT             0.435157 -0.360078  0.240969  0.111060  0.332188
# R99pTOT             0.721456 -0.368324 -0.159098 -0.096801  0.336509
# RX1day              0.275156 -0.206943 -0.143680 -0.066844  0.235218
# RX5day              0.345666 -0.261086  0.003560 -0.081875  0.250496
# SDII                0.195697 -0.365527  0.127376 -0.171431  0.415076
# CWD                -0.234881 -0.509571  0.079728 -0.156200  0.033959
# CDD                -0.289507 -0.301174  0.233367 -0.129959 -0.203435
# TNn                -0.288790  0.102012  0.302485  0.292938  0.038129
# TNx                -0.302231 -0.074138 -0.110631 -0.049224 -0.415740
# TXx                 0.156385 -0.089895 -0.091616 -0.095707 -0.134350
# TXn                -0.631565  0.299731  0.265263  0.213136 -0.304910
# Chirts_Tmax_Temp   -0.161682  0.201870 -0.293200  0.321721 -0.504999
# Chirts_Tmin_Temp   -0.292619  0.009236  0.113663  0.425302 -0.289520
# ERA5_Pressure      -0.245026  0.141319 -0.118884 -0.014946  0.089583
# ERA5_wins           0.249920 -0.020161 -0.054005  0.370406 -0.355811
# chirps_Prec         0.307710 -0.001248  0.151019  0.098209  0.495837
# ERA5_soil_moisture  0.158423 -0.184516  0.536510  0.021387  0.176743
# NDVI                0.334452 -0.004868  0.182484  0.093831  0.005393
# Sorgho              1.000000  1.000000  1.000000  1.000000  1.000000
#
#                       Sourou     Comoe    Leraba   Boulgou  Koulpelogo  ...  \
# PRCPTOT            -0.080872   -0.316077 -0.065582 -0.138107  0.042807
# R10mm               0.390921   -0.210783  0.062162 -0.172863 -0.013102
# R1mm               -0.187554    0.069549  0.236661  0.437078  0.224728
# R20mm              -0.107515   -0.269438 -0.344979 -0.065317  0.076575
# R5mm               -0.008007   -0.194279  0.589266  0.062393  0.066744
# R95pTOT            -0.202793   -0.265224 -0.480829 -0.076721 -0.027803
# R99pTOT             0.038929   -0.238066 -0.431839 -0.256574 -0.057631
# RX1day             -0.492106   -0.350556 -0.334689 -0.163073 -0.017470
# RX5day              0.004312   -0.202932 -0.352552 -0.183816  0.007962
# SDII                0.085659   -0.401727 -0.198825 -0.368818 -0.063632
# CWD                 0.128265    0.156393  0.352085  0.535759  0.271060
# CDD                -0.085030    0.181635 -0.201672 -0.326885 -0.264818
# TNn                 0.003947   -0.044808  0.027492  0.187108 -0.069692
# TNx                 0.111999   -0.161964 -0.034187  0.155202 -0.128446
# TXx                -0.114655   -0.449797  0.043251 -0.235241 -0.289854
# TXn                -0.178258    0.486733  0.286869  0.274709 -0.216570
# Chirts_Tmax_Temp   -0.191102   -0.438175  0.235330  0.157104  0.158127
# Chirts_Tmin_Temp    0.485707   -0.091225  0.108093  0.288167 -0.024579
# ERA5_Pressure       0.144807    0.339069  0.143304  0.100913  0.283239
# ERA5_wins          -0.031319   -0.135041 -0.066081 -0.285728 -0.231962
# chirps_Prec         0.097460   -0.276066  0.084593  0.034576  0.438450
# ERA5_soil_moisture  0.067247   -0.209848 -0.236439  0.090603 -0.131922
# NDVI                0.080315   -0.041946 -0.051833 -0.067477 -0.237277
# Sorgho              1.000000    1.000000  1.000000  1.000000  1.000000
#
# [37 rows x 45 columns]

# %%
# Out:
# 36     0.199802
# 134    0.323628
# 220    0.322950
# 299    0.307466
# 364    0.343466
# 468    0.348603
# 510    0.352233
# 538    0.338212
# 560    0.349102
# 577    0.330935
# 578    0.344484
# 600    0.205694
# 601    0.179945
# 602    0.190406
# Name: NDVI, dtype: float64

# %%
    dt=df.loc[df['province'].isin(['Kadiogo'])]
    X = dt.iloc[:, 1:38]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    y = dt.iloc[:, 36]
    X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI',36:'Sorgh0'})
    X=pd.DataFrame(X)
    a=pd.DataFrame(pd.DataFrame(X.corr()).iloc[:,36])
    a.columns=['Sissili']
    a
# Out:
#                      Sissili
# year                0.277167
# driver.TSA         -0.234917
# Driver.TNA          0.374834
# sahel_rainfall      0.440296
# QBO                -0.370935
# NAO                -0.297762
# gmsst               0.304412
# EA                 -0.582084
# AMM_sst             0.380830
# Driver.NTA          0.418869
# AMO_sst             0.329522
# Driver.AO          -0.287181
# PDO                 0.132951
# PRCPTOT             0.470003
# R10mm               0.568680
# R1mm                0.135516
# R20mm               0.247805
# R5mm                0.185548
# R95pTOT             0.669732
# R99pTOT             0.125169
# RX1day              0.262480
# RX5day              0.150911
# SDII                0.419936
# CWD                 0.040972
# CDD                -0.197064
# TNn                 0.105113
# TNx                -0.364380
# TXx                 0.039026
# TXn                -0.403119
# Chirts_Tmax_Temp   -0.320154
# Chirts_Tmin_Temp   -0.136789
# ERA5_Pressure       0.351781
# ERA5_wins           0.342143
# chirps_Prec         0.469213
# ERA5_soil_moisture  0.182323
# NDVI                0.044247
# Sorgh0              1.000000

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X = dt.iloc[:, 1:38]
y = X.iloc[:, 36]
X.corrwith(y, axis = 0)
# Out:
# year                  0.126296
# driver.TSA            0.160893
# Driver.TNA           -0.147845
# sahel_rainfall       -0.277732
# QBO                   0.314169
# NAO                   0.072941
# gmsst                -0.121874
# EA                   -0.129789
# AMM_sst              -0.207266
# Driver.NTA           -0.153189
# AMO_sst               0.020600
# Driver.AO             0.244880
# PDO                  -0.075652
# PRCPTOT               0.026850
# R10mm                -0.129425
# R1mm                 -0.003476
# R20mm                -0.071259
# R5mm                  0.358099
# R95pTOT              -0.218236
# R99pTOT               0.208239
# RX1day                0.062826
# RX5day                0.032505
# SDII                  0.041037
# CWD                  -0.155332
# CDD                  -0.352084
# TNn                   0.069980
# TNx                  -0.083549
# TXx                  -0.095326
# TXn                  -0.000582
# Chirts_Tmax_Temp      0.178621
# Chirts_Tmin_Temp      0.099838
# ERA5_Pressure        -0.168275
# ERA5_wins             0.051990
# chirps_Prec          -0.202112
# ERA5_soil_moisture   -0.131625
# NDVI                  0.059079
# sorgho                1.000000
# dtype: float64

# %%
b=pd.DataFrame()

# %%
dt=df.loc[df['province'].isin(['Nayala'])]
y = dt.iloc[:, 37]
a= pd.DataFrame(pd.DataFrame(dt.corrwith(y, axis = 0)).iloc[:,0])
a.columns=['Nayala']
# Out:
#                       Nayala
# year                0.018158
# driver.TSA          0.125947
# Driver.TNA         -0.012952
# sahel_rainfall      0.176630
# QBO                -0.361031
# NAO                -0.068691
# gmsst               0.172129
# EA                  0.050390
# AMM_sst             0.028437
# Driver.NTA         -0.007770
# AMO_sst            -0.139565
# Driver.AO          -0.000295
# PDO                -0.272469
# PRCPTOT             0.369328
# R10mm               0.367185
# R1mm                0.192304
# R20mm               0.620565
# R5mm               -0.211874
# R95pTOT             0.332188
# R99pTOT             0.336509
# RX1day              0.235218
# RX5day              0.250496
# SDII                0.415076
# CWD                 0.033959
# CDD                -0.203435
# TNn                 0.038129
# TNx                -0.415740
# TXx                -0.134350
# TXn                -0.304910
# Chirts_Tmax_Temp   -0.504999
# Chirts_Tmin_Temp   -0.289520
# ERA5_Pressure       0.089583
# ERA5_wins          -0.355811
# chirps_Prec         0.495837
# ERA5_soil_moisture  0.176743
# NDVI                0.005393
# sorgho              1.000000
