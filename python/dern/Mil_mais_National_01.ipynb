# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
import numpy as np
from sklearn.linear_model import RidgeCV,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
data=df=pd.read_csv("C:\\Users\\Yacou\\Desktop\\Yacouba_New\\climte\\Data\\Rendements\\okay\\mil_mais.csv")

# %%
col=data.columns
col
# Out:
# Index(['provinces', 'year', 'Tmin_ERA5', 'ERA5_Pressure', 'ERA5_Tmax',
#        'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
#        'Best_Temp', 'NDVI', 'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
#        'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
#        'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino', 'AMM',
#        'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'sahel_rainfal',
#        'tna', 'tsa', 'mais', 'mil'],
#       dtype='object')

# %%
c0=['provinces']
c1=['year', 'Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp',  'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino','sahel_rainfal','qbo' ]
c2=['NDVI','ERA5_soil_moisture','AMM',
       'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst',
       'tna', 'tsa']
d2=data[c2]
d3=data[ 'mil']
d4=data['mais']

# %%
d1=data[c1]
X = pd.DataFrame(StandardScaler().fit_transform(d1))
d1=X.rename(columns={0:'year', 1:'Tmin_ERA5', 2:'ERA5_Pressure',
        3:'ERA5_wins', 4:'ARC2_year', 5:'Best_Temp_Max',
       6:'Best_Temp', 7:'Tamsat_Prec', 8:'chirps_Prec', 9:'CDD', 10:'CWD',
       11:'PRCPTOT', 12:'R10mm', 13:'R1mm', 14:'R20mm', 15:'R5mm', 16:'R95pTOT', 17:'R99pTOT',
       18:'RX1day', 19:'RX5day', 20:'SDII', 21:'TNn', 22:'TXn', 23:'TNx', 24:'TXx', 25:'Nino',26:'sahel_rainfal',27:'qbo'})

# %%
dt=pd.concat([data[c0],d1,d2,d3,d4],axis=1)
dt
# Out:
#       provinces      year  Tmin_ERA5  ERA5_Pressure  ERA5_wins  ARC2_year  \
# 0          Bale -1.638356  -1.087528      -0.370056  -0.454051  -0.190868
# 1         Banwa -1.638356  -1.207182      -0.380800  -0.414125   0.305342
# 2          Bale -1.445608  -0.847959       0.735889  -0.260182  -0.274032
# 3         Kossi -1.638356  -0.292140      -1.180025  -0.512948  -0.664539
# 4          Bale -1.252861  -0.048313       0.262063  -0.027426  -0.554506
# ..          ...       ...        ...            ...        ...        ...
# 805     Zondoma  1.445608   0.607924       0.064498  -0.419878   0.571828
# 806     Yatenga  1.638356   0.958150      -0.454895   0.110027   0.110653
# 807        Ziro  1.638356  -0.542672       1.001500  -0.306143   0.552101
# 808  Zoundweogo  1.638356  -0.063794       0.788359  -0.175251   0.851918
# 809     Zondoma  1.638356   0.483643      -0.059994  -0.390351   0.011487
#
#      Best_Temp_Max  Best_Temp  Tamsat_Prec  chirps_Prec  ...        AO  \
# 0        -0.354215  -1.166262    -0.469743    -0.092878  ...  0.425333
# 1        -0.683454  -1.383374    -0.251991    -0.343494  ...  0.425333
# 2        -0.520714  -0.981679     0.584017     0.343589  ...  0.447667
# 3         0.003042  -0.601474    -0.644021    -0.941824  ...  0.425333
# 4         0.033129  -0.072216     0.563520    -0.261517  ...  0.574000
# ..             ...        ...          ...          ...  ...       ...
# 805       0.216633   0.790537     0.029485     0.012239  ... -0.258333
# 806       0.938027   1.485328    -1.084946    -0.577379  ... -0.139000
# 807      -0.638153  -0.300305     0.147152     0.378733  ... -0.139000
# 808      -0.609218  -0.215582    -0.003973    -0.001632  ... -0.139000
# 809       0.551938   0.990830    -0.674718    -0.452504  ... -0.139000
#
#            EA       NAO       NTA       PDO     gmsst       tna       tsa  \
# 0   -0.110000  0.540000 -0.206667 -0.046667  0.626667 -0.076667  0.286667
# 1   -0.110000  0.540000 -0.206667 -0.046667  0.626667 -0.076667  0.286667
# 2    0.456667 -0.003333 -0.010000 -0.360000  0.663333  0.116667  0.403333
# 3   -0.110000  0.540000 -0.206667 -0.046667  0.626667 -0.076667  0.286667
# 4    0.106667  0.560000 -0.120000 -0.433333  0.773333 -0.113333  0.376667
# ..        ...       ...       ...       ...       ...       ...       ...
# 805 -1.446667 -0.180000  0.296667  2.333333  1.206667  0.363333  0.473333
# 806  0.843333  0.123333  0.463333  0.930000  1.093333  0.550000  0.480000
# 807  0.843333  0.123333  0.463333  0.930000  1.093333  0.550000  0.480000
# 808  0.843333  0.123333  0.463333  0.930000  1.093333  0.550000  0.480000
# 809  0.843333  0.123333  0.463333  0.930000  1.093333  0.550000  0.480000
#
#              mil         mais
# 0     960.581652  1459.049128
# 1    1029.044240  1308.239124
# 2     979.593220  1750.949650
# 3     550.000000   535.000000
# 4     850.526316  1578.408370
# ..           ...          ...
# 805   638.142700   793.429896
# 806   658.394064   813.503311
# 807   706.659920  1237.511702
# 808  1019.297740  1768.268712
# 809   574.007230   956.272299
#
# [810 rows x 43 columns]

# %%
#var = pd.get_dummies(df[c0],drop_first=True)

# %%
#dt0=pd.concat([var,d1,d2],axis=1)
#y=data['mil']

# %%
drivers=['year','AMM','AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'tna', 'tsa','Nino','sahel_rainfal']

indices=['year', 'CDD', 'CWD','PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx']

meteo= ['year', 'Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max','Best_Temp','Tamsat_Prec', 'chirps_Prec', 'NDVI','ERA5_soil_moisture' ]

ind_driver=['year', 'CDD', 'CWD','PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx',
            'AMM','AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'tna', 'tsa','Nino','sahel_rainfal']

ind_meteo=['year', 'CDD', 'CWD','PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx','Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max','Best_Temp','Tamsat_Prec', 'chirps_Prec', 'NDVI','ERA5_soil_moisture' ]

meteo_driver=['year', 'Tmin_ERA5', 'ERA5_Pressure','ERA5_wins', 'ARC2_year', 'Best_Temp_Max','Best_Temp','Tamsat_Prec',
              'chirps_Prec', 'NDVI','ERA5_soil_moisture', 
              'AMM','AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'tna', 'tsa','Nino','sahel_rainfal']

All=['year', 'Tmin_ERA5', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp', 'NDVI', 'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino', 'AMM',
       'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'sahel_rainfal',
       'tna', 'tsa']

c0=['provinces']

# %%
t1=model(dt,1,meteo,'mais')

# %%
t1.prediction()
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.942009    0.634249
# 1  DecisionTree     0.999977    0.335181
# 2       RidgeCV     0.592113    0.589218
# 3         Lasso     0.568019    0.576498

# %%
def model(df,n,predicteur,var):
    pred=df[predicteur]
    y=df[var]
    dum = pd.get_dummies(df[c0],drop_first=True)
    X=pd.concat([dum,pred],axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=n) 

    model1 = RidgeCV()
    model2 = Lasso(normalize=True, tol=1e-3)
    model3 = RandomForestRegressor(n_estimators = 500,max_depth=80)
    model4 = DecisionTreeRegressor(max_depth=23) 

    model1.fit(X_train, y_train)
    model2.fit(X_train, y_train)
    model3.fit(X_train, y_train)
    model4.fit(X_train, y_train)

    train_RidgeCV=model1.score(X_train, y_train)
    test_RidgeCV=model1.score(X_test, y_test)

    train_LassoCV=model2.score(X_train, y_train)
    test_LassoCV=model2.score(X_test, y_test)

    train_RandomForest=model3.score(X_train, y_train)
    test_RandomForest=model3.score(X_test, y_test)

    train_DecisionTree=model4.score(X_train, y_train)
    test_DecisionTree=model4.score(X_test, y_test)


    data = {'model': ['RandomForest', 'DecisionTree', 'RidgeCV', 'Lasso'],
        'Score_train': [train_RandomForest, train_DecisionTree, train_RidgeCV, train_LassoCV],
        'score_test': [test_RandomForest, test_DecisionTree, test_RidgeCV, test_LassoCV]
        }

   # data = {'model': ['RandomForest', 'DecisionTree'],
     #   'Score_train': [train_RandomForest, train_DecisionTree],
     #   'score_test': [test_RandomForest, test_DecisionTree]
     #   }

    d = pd.DataFrame(data)
    return d

# %%
model(dt,1,meteo,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.940978    0.636045
# 1  DecisionTree     0.999977    0.409967
# 2       RidgeCV     0.592113    0.589218
# 3         Lasso     0.568019    0.576498

# %%
model(dt,1,meteo,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.889170    0.275994
# 1  DecisionTree     0.999997   -0.504306
# 2       RidgeCV     0.270572    0.251495
# 3         Lasso     0.128327    0.128914

# %%
model(dt,1,drivers,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.830895    0.563986
# 1  DecisionTree     0.841909    0.404307
# 2       RidgeCV     0.665885    0.655314
# 3         Lasso     0.519891    0.506657

# %%
model(dt,1,drivers,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.871964    0.120737
# 1  DecisionTree     0.775869   -0.091100
# 2       RidgeCV     0.341942    0.368257
# 3         Lasso     0.113552    0.095658

# %%
model(dt,1,indices,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.930836    0.511666
# 1  DecisionTree     0.999732    0.125516
# 2       RidgeCV     0.633870    0.584247
# 3         Lasso     0.541139    0.506080

# %%
model(dt,1,indices,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.882847    0.261290
# 1  DecisionTree     0.999940   -1.600360
# 2       RidgeCV     0.332005    0.298565
# 3         Lasso     0.153520    0.149324

# %%
model(dt,1,ind_driver,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.933710    0.523262
# 1  DecisionTree     0.999082    0.109960
# 2       RidgeCV     0.691060    0.664085
# 3         Lasso     0.555656    0.541046

# %%
model(dt,1,ind_driver,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.888240    0.285449
# 1  DecisionTree     0.986715   -0.867480
# 2       RidgeCV     0.353221    0.376602
# 3         Lasso     0.166671    0.169797

# %%
model(dt,1,ind_meteo,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.938715    0.620764
# 1  DecisionTree     1.000000    0.251581
# 2       RidgeCV     0.613577    0.582662
# 3         Lasso     0.570650    0.576778

# %%
model(dt,1,ind_meteo,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.880344    0.250024
# 1  DecisionTree     0.997488   -0.663034
# 2       RidgeCV     0.311045    0.279186
# 3         Lasso     0.153570    0.150290

# %%
model(dt,1,meteo_driver,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.943277    0.644828
# 1  DecisionTree     0.999591    0.354647
# 2       RidgeCV     0.679918    0.681781
# 3         Lasso     0.583512    0.601298

# %%
model(dt,1,meteo_driver,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.889006    0.306312
# 1  DecisionTree     0.987797   -0.662491
# 2       RidgeCV     0.329618    0.350178
# 3         Lasso     0.147773    0.148010

# %%
model(dt,1,All,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.941292    0.629956
# 1  DecisionTree     1.000000    0.421939
# 2       RidgeCV     0.642465    0.621043
# 3         Lasso     0.584009    0.597665

# %%
model(dt,1,All,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.886926    0.300251
# 1  DecisionTree     0.996288   -0.698570
# 2       RidgeCV     0.360550    0.376395
# 3         Lasso     0.166528    0.170145

# %%
a=pd.DataFrame(pd.DataFrame(dt.corr()).iloc[:,40:42]) 
a
# Out:
#                          mil      mais
# year               -0.005770  0.169005
# Tmin_ERA5          -0.271013 -0.515785
# ERA5_Pressure       0.292826  0.579856
# ERA5_wins          -0.230771 -0.413070
# ARC2_year           0.277525  0.519562
# Best_Temp_Max      -0.312863 -0.532655
# Best_Temp          -0.284774 -0.481035
# Tamsat_Prec         0.276793  0.555498
# chirps_Prec         0.312999  0.588642
# CDD                -0.039683 -0.141282
# CWD                 0.183227  0.180663
# PRCPTOT             0.293169  0.523740
# R10mm               0.265731  0.487730
# R1mm                0.316274  0.464909
# R20mm               0.200302  0.401527
# R5mm                0.326752  0.466679
# R95pTOT             0.095158  0.207316
# R99pTOT             0.017288  0.086299
# RX1day              0.176455  0.382176
# RX5day              0.131895  0.282080
# SDII                0.177572  0.369844
# TNn                -0.265915 -0.443583
# TXn                -0.234435 -0.415451
# TNx                -0.298451 -0.475713
# TXx                -0.235805 -0.505442
# Nino                0.120209  0.132441
# sahel_rainfal      -0.065407  0.121817
# qbo                -0.009983 -0.073126
# NDVI               -0.016483  0.004245
# ERA5_soil_moisture  0.272266  0.533921
# AMM                 0.076754 -0.010343
# AMO                 0.044475  0.061121
# AO                 -0.042195 -0.035080
# EA                 -0.130603 -0.154906
# NAO                -0.034931 -0.124787
# NTA                 0.069468  0.051900
# PDO                 0.077756  0.085197
# gmsst              -0.049329  0.109627
# tna                 0.066465  0.030598
# tsa                -0.148253  0.015214
# mil                 1.000000  0.511638
# mais                0.511638  1.000000

# %%
All_2=['Tmin_ERA5', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp',  'Tamsat_Prec', 'chirps_Prec', 
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx']

# %%
model(dt,1,All_2,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.937867    0.615043
# 1  DecisionTree     0.998110    0.180921
# 2       RidgeCV     0.659003    0.662834
# 3         Lasso     0.565699    0.580446

# %%
model(dt,1,All_2,'mil')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.877754    0.248343
# 1  DecisionTree     0.999937   -1.013257
# 2       RidgeCV     0.301612    0.277189
# 3         Lasso     0.153564    0.150337

# %%
450-337.5
# Out:
# 112.5
