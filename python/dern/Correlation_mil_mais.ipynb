# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler

# %%
data=df=pd.read_csv("C:\\Users\\Yacou\\Desktop\\Yacouba_New\\climte\\Data\\Rendements\\okay\\mil_mais.csv")
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']
len(vect)
# Out:
# 45

# %%
df
# Out:
#       provinces  year   Tmin_ERA5  ERA5_Pressure   ERA5_Tmax  \
# 0          Bale  2000  295.346261    101164.2983  303.090003
# 1         Banwa  2000  295.255481    101163.6513  303.142447
# 2          Bale  2001  295.528019    101230.8929  302.867590
# 3         Kossi  2000  295.949711    101115.5259  304.451160
# 4          Bale  2002  296.134700    101202.3614  304.007824
# ..          ...   ...         ...            ...         ...
# 805     Zondoma  2016  296.632578    101190.4650  305.163821
# 806     Yatenga  2017  296.898290    101159.1897  305.863082
# 807        Ziro  2017  295.759636    101246.8867  303.227227
# 808  Zoundweogo  2017  296.122954    101234.0524  303.601853
# 809     Zondoma  2017  296.538288    101182.9687  305.027763
#
#      ERA5_soil_moisture  ERA5_wins   ARC2_year  Best_Temp_Max  Best_Temp  ...  \
# 0              0.387494   2.297034  773.367238      33.156278  20.839313  ...
# 1              0.325074   2.308840  844.566249      32.867129  20.635878  ...
# 2              0.384737   2.354358  761.434378      33.010053  21.012269  ...
# 3              0.296759   2.279619  705.402388      33.470032  21.368522  ...
# 4              0.361794   2.423180  721.190411      33.496455  21.864440  ...
# ..                  ...        ...         ...            ...        ...  ...
# 805            0.200586   2.307139  882.803056      33.657614  22.672844  ...
# 806            0.173094   2.463822  816.631204      34.291164  23.323867  ...
# 807            0.316436   2.340768  879.972562      32.906914  21.650720  ...
# 808            0.339022   2.379471  922.991941      32.932326  21.730105  ...
# 809            0.204287   2.315869  802.402198      33.952089  22.860520  ...
#
#           NAO       NTA       PDO     gmsst        qbo  sahel_rainfal  \
# 0    0.540000 -0.206667 -0.046667  0.626667  -1.613333      -1.333333
# 1    0.540000 -0.206667 -0.046667  0.626667  -1.613333      -1.333333
# 2   -0.003333 -0.010000 -0.360000  0.663333 -20.676667      41.000000
# 3    0.540000 -0.206667 -0.046667  0.626667  -1.613333      -1.333333
# 4    0.560000 -0.120000 -0.433333  0.773333  13.816667     -74.666667
# ..        ...       ...       ...       ...        ...            ...
# 805 -0.180000  0.296667  2.333333  1.206667   2.290000      64.666667
# 806  0.123333  0.463333  0.930000  1.093333   6.236667     184.666667
# 807  0.123333  0.463333  0.930000  1.093333   6.236667     184.666667
# 808  0.123333  0.463333  0.930000  1.093333   6.236667     184.666667
# 809  0.123333  0.463333  0.930000  1.093333   6.236667     184.666667
#
#           tna       tsa         mais          mil
# 0   -0.076667  0.286667  1459.049128   960.581652
# 1   -0.076667  0.286667  1308.239124  1029.044240
# 2    0.116667  0.403333  1750.949650   979.593220
# 3   -0.076667  0.286667   535.000000   550.000000
# 4   -0.113333  0.376667  1578.408370   850.526316
# ..        ...       ...          ...          ...
# 805  0.363333  0.473333   793.429896   638.142700
# 806  0.550000  0.480000   813.503311   658.394064
# 807  0.550000  0.480000  1237.511702   706.659920
# 808  0.550000  0.480000  1768.268712  1019.297740
# 809  0.550000  0.480000   956.272299   574.007230
#
# [810 rows x 44 columns]

# %%
col=data.columns
col
# Out:
# Index(['provinces', 'year', 'Tmin_ERA5', 'ERA5_Pressure', 'ERA5_Tmax',
#        'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
#        'Best_Temp', 'NDVI', 'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
#        'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
#        'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino', 'AMM',
#        'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'sahel_rainfal',
#        'tna', 'tsa', 'mais', 'mil'],
#       dtype='object')

# %%
#df=data=df.loc[df['provinces'].isin(["Bale"])]
#df.reset_index(inplace=True, drop=True)
#df

# %%
c0=['provinces']
c1=['year', 'Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp',  'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino','sahel_rainfal','qbo','ERA5_Tmax' ]

c2=['NDVI','ERA5_soil_moisture','AMM',
       'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst',
       'tna', 'tsa']
d2=data[c2]
d3=data[ 'mil']
d4=data['mais']

# %%
d1=data[c1]
X = pd.DataFrame(StandardScaler().fit_transform(d1))
d1=X.rename(columns={0:'year', 1:'Tmin_ERA5', 2:'ERA5_Pressure',
        3:'ERA5_wins', 4:'ARC2_year', 5:'Best_Temp_Max',
       6:'Best_Temp', 7:'Tamsat_Prec', 8:'chirps_Prec', 9:'CDD', 10:'CWD',
       11:'PRCPTOT', 12:'R10mm', 13:'R1mm', 14:'R20mm', 15:'R5mm', 16:'R95pTOT', 17:'R99pTOT',
       18:'RX1day', 19:'RX5day', 20:'SDII', 21:'TNn', 22:'TXn', 23:'TNx', 24:'TXx', 25:'Nino',26:'sahel_rainfal',27:'qbo',28:'ERA5_Tmax'})

# %%
dt=pd.concat([data[c0],d1,d2,d3,d4],axis=1)
a=pd.DataFrame(pd.DataFrame(pd.DataFrame(dt.corr()))['mais'])
a
# Out:
#                         mais
# year                0.169005
# Tmin_ERA5          -0.515785
# ERA5_Pressure       0.579856
# ERA5_wins          -0.413070
# ARC2_year           0.519562
# Best_Temp_Max      -0.532655
# Best_Temp          -0.481035
# Tamsat_Prec         0.555498
# chirps_Prec         0.588642
# CDD                -0.141282
# CWD                 0.180663
# PRCPTOT             0.523740
# R10mm               0.487730
# R1mm                0.464909
# R20mm               0.401527
# R5mm                0.466679
# R95pTOT             0.207316
# R99pTOT             0.086299
# RX1day              0.382176
# RX5day              0.282080
# SDII                0.369844
# TNn                -0.443583
# TXn                -0.415451
# TNx                -0.475713
# TXx                -0.505442
# Nino                0.132441
# sahel_rainfal       0.121817
# qbo                -0.073126
# ERA5_Tmax          -0.568660
# NDVI                0.004245
# ERA5_soil_moisture  0.533921
# AMM                -0.010343
# AMO                 0.061121
# AO                 -0.035080
# EA                 -0.154906
# NAO                -0.124787
# NTA                 0.051900
# PDO                 0.085197
# gmsst               0.109627
# tna                 0.030598
# tsa                 0.015214
# mil                 0.511638
# mais                1.000000

# %%
def correlation(df,level,c1,c2,crop):
    dt=df.loc[df['provinces'].isin([level])]
    dt.reset_index(inplace=True, drop=True)
    d1=dt[c1]
    d2=dt[c2]
    d3=dt[ 'mil']
    d4=dt['mais']
    X = pd.DataFrame(StandardScaler().fit_transform(d1))
    d1=X.rename(columns={0:'year', 1:'Tmin_ERA5', 2:'ERA5_Pressure',
        3:'ERA5_wins', 4:'ARC2_year', 5:'Best_Temp_Max',
       6:'Best_Temp', 7:'Tamsat_Prec', 8:'chirps_Prec', 9:'CDD', 10:'CWD',
       11:'PRCPTOT', 12:'R10mm', 13:'R1mm', 14:'R20mm', 15:'R5mm', 16:'R95pTOT', 17:'R99pTOT',
       18:'RX1day', 19:'RX5day', 20:'SDII', 21:'TNn', 22:'TXn', 23:'TNx', 24:'TXx', 25:'Nino',26:'sahel_rainfal',
       27:'qbo',28:'ERA5_Tmax'})
    dd=pd.concat([d1,d2,d3,d4],axis=1)
    a=pd.DataFrame(pd.DataFrame(pd.DataFrame(dd.corr()))[crop])
    a.columns=[level]
    return a

# %%
correlation(df,'Bale',c1,c2,'mais')
# Out:
#                         Bale
# year                0.433653
# Tmin_ERA5           0.265952
# ERA5_Pressure       0.367294
# ERA5_wins          -0.154716
# ARC2_year           0.389694
# Best_Temp_Max      -0.127809
# Best_Temp          -0.118077
# Tamsat_Prec         0.370850
# chirps_Prec         0.565513
# CDD                -0.305569
# CWD                 0.224439
# PRCPTOT             0.555793
# R10mm               0.548065
# R1mm                0.468758
# R20mm               0.400931
# R5mm                0.655040
# R95pTOT             0.209945
# R99pTOT             0.401492
# RX1day              0.418582
# RX5day              0.349692
# SDII                0.431856
# TNn                -0.175405
# TXn                -0.093717
# TNx                 0.025126
# TXx                 0.269059
# Nino                0.345514
# sahel_rainfal       0.039998
# qbo                -0.131710
# ERA5_Tmax           0.086251
# NDVI               -0.210386
# ERA5_soil_moisture  0.146716
# AMM                -0.199629
# AMO                -0.109800
# AO                  0.203349
# EA                 -0.587380
# NAO                -0.033320
# NTA                -0.015258
# PDO                 0.136845
# gmsst               0.303752
# tna                -0.066133
# tsa                 0.246735
# mil                 0.200753
# mais                1.000000

# %%
def table(df,v,c1,c2,crop):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        D=pd.concat([D,correlation(df,v[i],c1,c2,crop)],axis = 1)
    return D

# %%
table(df,vect,c1,c2,"mais")
# Out:
#                         Bale     Banwa     Kossi   Mouhoun    Nayala  \
# year                0.433653  0.065984  0.214248  0.081729 -0.001654
# Tmin_ERA5           0.265952  0.082730  0.115892  0.198087  0.078888
# ERA5_Pressure       0.367294  0.051525  0.222699  0.327872  0.172136
# ERA5_wins          -0.154716  0.066862  0.136492  0.168734  0.163667
# ARC2_year           0.389694  0.171460  0.348202  0.227524  0.262714
# Best_Temp_Max      -0.127809  0.034505 -0.120279 -0.043785 -0.054684
# Best_Temp          -0.118077 -0.208186 -0.085074 -0.025464 -0.115689
# Tamsat_Prec         0.370850 -0.039654 -0.004839  0.166469 -0.001346
# chirps_Prec         0.565513  0.216475  0.379579  0.289897  0.242784
# CDD                -0.305569 -0.205900 -0.122391  0.208139 -0.236809
# CWD                 0.224439 -0.261406  0.382813 -0.039483  0.095847
# PRCPTOT             0.555793  0.039749  0.336338  0.193551  0.165133
# R10mm               0.548065  0.043043  0.389262  0.030560  0.223025
# R1mm                0.468758  0.294820  0.330146  0.494877  0.435764
# R20mm               0.400931 -0.001719  0.263922  0.232169 -0.199179
# R5mm                0.655040  0.034038  0.418580  0.294979  0.402743
# R95pTOT             0.209945 -0.102788  0.182151  0.284895 -0.085066
# R99pTOT             0.401492 -0.046142  0.016613 -0.062487 -0.104185
# RX1day              0.418582  0.148145 -0.023289 -0.127629 -0.163418
# RX5day              0.349692  0.082203  0.020472  0.034716 -0.232944
# SDII                0.431856 -0.085606  0.245802  0.000544 -0.199634
# TNn                -0.175405 -0.090462 -0.104408 -0.062708 -0.159462
# TXn                -0.093717  0.052886 -0.028907  0.194046  0.131431
# TNx                 0.025126 -0.323308 -0.275186 -0.227037 -0.431610
# TXx                 0.269059  0.334038  0.307386  0.264808  0.276620
# Nino                0.345514 -0.057445  0.106740  0.132115  0.065674
# sahel_rainfal       0.039998  0.130358  0.350542  0.068428 -0.005679
# qbo                -0.131710  0.008795 -0.137906  0.051598 -0.063906
# ERA5_Tmax           0.086251 -0.023030 -0.135466  0.073504 -0.182853
# NDVI               -0.210386  0.215514  0.019091 -0.037634 -0.077188
# ERA5_soil_moisture  0.146716 -0.020968  0.171661 -0.019096  0.197004
# AMM                -0.199629  0.190074  0.305565  0.097272 -0.011656
# AMO                -0.109800  0.268459  0.460490  0.221456  0.186717
# AO                  0.203349 -0.023081 -0.004136  0.155324  0.292329
# EA                 -0.587380 -0.413416 -0.354081 -0.465773 -0.347732
# NAO                -0.033320 -0.089535 -0.096317  0.027439  0.120329
# NTA                -0.015258  0.290783  0.440126  0.170253  0.063956
# PDO                 0.136845  0.032953  0.281005  0.220071  0.160288
# gmsst               0.303752 -0.111804  0.062779 -0.055756 -0.096232
# tna                -0.066133  0.288584  0.416954  0.128910  0.057418
# tsa                 0.246735  0.208801  0.203624 -0.101979  0.094269
# mil                 0.200753 -0.218917  0.350949  0.791023  0.320786
# mais                1.000000  1.000000  1.000000  1.000000  1.000000
#
#                       Sourou     Comoe    Leraba   Boulgou  Koulpelogo  ...  \
# year                0.215066  0.358736  0.170650  0.180748   -0.587912  ...
# Tmin_ERA5           0.121507  0.402201  0.045498  0.486940   -0.174934  ...
# ERA5_Pressure       0.340604  0.199389  0.060805  0.398467   -0.082303  ...
# ERA5_wins           0.251572 -0.093616  0.355246  0.074216    0.348303  ...
# ARC2_year           0.087835  0.330313  0.022838 -0.127023   -0.457392  ...
# Best_Temp_Max      -0.119002  0.433405  0.155058 -0.013659   -0.224251  ...
# Best_Temp          -0.149197  0.443952  0.148750  0.257340   -0.005252  ...
# Tamsat_Prec         0.002071  0.108541  0.013446  0.289598   -0.297314  ...
# chirps_Prec         0.127312  0.139324 -0.066469 -0.086563   -0.321512  ...
# CDD                -0.635988  0.186050 -0.004068 -0.056196    0.268247  ...
# CWD                 0.393427  0.232414 -0.344602 -0.125441   -0.323933  ...
# PRCPTOT             0.126632  0.003206 -0.091550 -0.120329   -0.300866  ...
# R10mm              -0.014188 -0.134718 -0.350914 -0.092651   -0.173244  ...
# R1mm                0.388094  0.128401  0.297711  0.170114   -0.320408  ...
# R20mm               0.303400  0.135713 -0.002894 -0.148131   -0.085596  ...
# R5mm                0.125558 -0.234976  0.067700  0.257456   -0.008426  ...
# R95pTOT             0.172951  0.104546  0.041309 -0.519860   -0.171237  ...
# R99pTOT             0.017603 -0.051139  0.083530 -0.588681   -0.148898  ...
# RX1day             -0.127113  0.131291  0.342237 -0.632715   -0.036038  ...
# RX5day             -0.154161 -0.043786  0.195157 -0.554648   -0.166891  ...
# SDII               -0.201887 -0.092654 -0.366073 -0.290131    0.003339  ...
# TNn                -0.162838  0.426321 -0.047659  0.331937   -0.030187  ...
# TXn                -0.086492  0.768601  0.307788  0.042228    0.024115  ...
# TNx                -0.248808  0.317941  0.241131  0.039765   -0.106897  ...
# TXx                 0.202433  0.178029 -0.030504 -0.261216   -0.217968  ...
# Nino                0.264695  0.300230 -0.058378  0.384831   -0.217482  ...
# sahel_rainfal       0.035773  0.055536 -0.210749  0.186038    0.141981  ...
# qbo                -0.176979  0.324814 -0.163234  0.070990    0.117178  ...
# ERA5_Tmax          -0.104455  0.403908 -0.026863  0.344602   -0.104449  ...
# NDVI                0.192188  0.045240  0.265633 -0.015858    0.000110  ...
# ERA5_soil_moisture  0.079015 -0.083301 -0.292529 -0.204023   -0.123930  ...
# AMM                 0.194065 -0.127685  0.181025  0.125140    0.095910  ...
# AMO                 0.239529  0.173554  0.117721  0.262673    0.081171  ...
# AO                  0.068044  0.025821  0.172514 -0.067097   -0.284425  ...
# EA                 -0.395675 -0.247931 -0.560039 -0.156991    0.035085  ...
# NAO                -0.070717 -0.006670 -0.053560  0.025725   -0.167628  ...
# NTA                 0.267073  0.017468  0.238822  0.236533   -0.010087  ...
# PDO                 0.258649  0.288550 -0.002563  0.318289   -0.097390  ...
