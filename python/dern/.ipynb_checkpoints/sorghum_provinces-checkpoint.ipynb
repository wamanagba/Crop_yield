# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import RidgeCV,LassoCV,Lasso
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
data=df=pd.read_csv("C:\\Users\\Yacou\\Desktop\\Yacouba_New\\climte\\Data\\Rendements\\okay\\sorgho.csv")

# %%
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']

# %%
col=data.columns
col
# Out:
# Index(['provinces', 'year', 'Tmin_ERA5', 'ERA5_Pressure', 'ERA5_Tmax',
#        'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
#        'Best_Temp', 'NDVI', 'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
#        'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
#        'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino', 'AMM',
#        'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'sahel_rainfal',
#        'tna', 'tsa', 'sorgho_b', 'sorgho_r'],
#       dtype='object')

# %%
c0=['provinces']
c1=['year', 'Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp',  'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino','sahel_rainfal','qbo' ]
c2=['NDVI','ERA5_soil_moisture','AMM',
       'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst',
       'tna', 'tsa']
d2=data[c2]
d3=data[ 'sorgho_b']
d4=data['sorgho_r']

# %%
ind1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal',
       'NAO','gmsst', 'R99pTOT', 'PDO', 'qbo', 'AMO','NTA', 'AO','mil','mais']

c1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal']

c2=['NAO','gmsst', 'R99pTOT', 'PDO', 'qbo', 'AMO','NTA', 'AO']

# %%
dt=df.loc[df['provinces'].isin(['Kadiogo'])]

# %%
var=[ 'R5mm', 'R1mm', 'chirps_Prec', 'PRCPTOT',
       'ERA5_Pressure', 'ERA5_soil_moisture',
       'R10mm', 'R20mm', 'CWD', 'SDII', 'RX1day', 'RX5day', 'Nino', 'R95pTOT',
       'PDO', 'AMM', 'NTA', 'tna', 'AMO', 'R99pTOT', 'year', 'qbo',
       'NAO', 'CDD', 'AO', 'gmsst', 'sahel_rainfal', 
       ]

# %%
c1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal','R99pTOT']
d1=df[c1]
    
c2=['NAO','gmsst','PDO', 'qbo', 'AMO','NTA', 'AO']
    # millet variables
    
    #c1= ['R5mm', 'R1mm', 'chirps_Prec', 'PRCPTOT','ERA5_Pressure', 'ERA5_soil_moisture',
    #'R10mm', 'R20mm', 'CWD', 'SDII', 'RX1day', 'RX5day', 'Nino', 'R95pTOT','R99pTOT', 'year', 'CDD', 'sahel_rainfal']
    #d1=dt[c1]
    
    #c2=['NAO','gmsst','PDO','AMM','tna', 'qbo', 'AMO','NTA', 'AO']
    
    
d2=df[c2]
d2=d2.reset_index(drop=True)
y = df['sorgho_r']
    
d1 = pd.DataFrame(StandardScaler().fit_transform(d1))
X=pd.concat([d1,d2],axis=1)

# %%
y
# Out:
# 0      1112.857143
# 1      1200.000000
# 2       537.710646
# 3      1072.000000
# 4      1299.509391
#           ...
# 670       0.000000
# 671       0.000000
# 672     994.785113
# 673    1470.652386
# 674       0.000000
# Name: sorgho_r, Length: 675, dtype: float64

# %%
def model(df,n,crop):
    # mais variables
    c1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal','R99pTOT']
    d1=df[c1]
    
    c2=['NAO','gmsst','PDO', 'qbo', 'AMO','NTA', 'AO']
    # millet variables
    
    #c1= ['R5mm', 'R1mm', 'chirps_Prec', 'PRCPTOT','ERA5_Pressure', 'ERA5_soil_moisture',
    #'R10mm', 'R20mm', 'CWD', 'SDII', 'RX1day', 'RX5day', 'Nino', 'R95pTOT','R99pTOT', 'year', 'CDD', 'sahel_rainfal']
    #d1=dt[c1]
    
    #c2=['NAO','gmsst','PDO','AMM','tna', 'qbo', 'AMO','NTA', 'AO']
    
    
    d2=df[c2]
    d2=d2.reset_index(drop=True)
    y = df[crop]
    
    d1 = pd.DataFrame(StandardScaler().fit_transform(d1))
    X=pd.concat([d1,d2],axis=1)
    
    y=pd.array(y)
    y=pd.DataFrame(y)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.1,random_state=n)


    model1 = RidgeCV()
    model2 = Lasso(normalize=True, tol=1e-3)
    model3 = RandomForestRegressor(n_estimators = 200,max_depth=23)
    model4 = DecisionTreeRegressor(max_depth=5) 

    model1.fit(X_train, y_train.values.ravel())
    model2.fit(X_train, y_train.values.ravel())
    model3.fit(X_train, y_train.values.ravel())
    model4.fit(X_train, y_train.values.ravel())

    train_RidgeCV=model1.score(X_train, y_train)
    test_RidgeCV=model1.score(X_test, y_test)

    train_LassoCV=model2.score(X_train, y_train)
    test_LassoCV=model2.score(X_test, y_test)

    train_RandomForest=model3.score(X_train, y_train)
    test_RandomForest=model3.score(X_test, y_test)

    train_DecisionTree=model4.score(X_train, y_train)
    test_DecisionTree=model4.score(X_test, y_test)


    data = {'model': ['RandomForest', 'DecisionTree', 'RidgeCV', 'Lasso'],
        'Score_train': [train_RandomForest, train_DecisionTree, train_RidgeCV, train_LassoCV],
        'score_test': [test_RandomForest, test_DecisionTree, test_RidgeCV, test_LassoCV]
        }

   # data = {'model': ['RandomForest', 'DecisionTree'],
     #   'Score_train': [train_RandomForest, train_DecisionTree],
     #   'score_test': [test_RandomForest, test_DecisionTree]
     #   }

    d = pd.DataFrame(data)
    return d

# %%
d=dt.loc[dt['provinces'].isin(['Kadiogo'])]
model(d,2,'sorgho_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f924df5c375f> in <module>
# ----> 1 d=dt.loc[dt['provinces'].isin(['Kadiogo'])]
#       2 model(d,2,'sorgho_r')
#
# NameError: name 'dt' is not defined

# %%
def model_province(dt,prov,n,crop):
    m=prov
    m=np.repeat(m,4, axis=0)
    m={'provinces':m}
    m=pd.DataFrame(m)
    d=dt.loc[dt['provinces'].isin([prov])] #(X, y,test_size=0.17,random_state=3)
    m=pd.concat([m,model(d,n,crop)],axis = 1)
    return m

# %%
model_province(df,'Kadiogo',2,'sorgho_r')
# Out:
#   provinces         model  Score_train  score_test
# 0   Kadiogo  RandomForest     0.843311   -0.271567
# 1   Kadiogo  DecisionTree     0.999924   -0.057256
# 2   Kadiogo       RidgeCV     0.778952    0.598592
# 3   Kadiogo         Lasso     0.995150    0.653110

# %%
def Data(data,v,n,crop):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        P=v[i]
        D=pd.concat([D,model_province(data,P,n,crop)],axis = 0)
    return D

# %%
ok=Data(df,vect,2,'sorgho_r')
ok
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
#    provinces         model  Score_train   score_test
# 0       Bale  RandomForest     0.844073  -289.041138
# 1       Bale  DecisionTree     0.999685  -252.785616
# 2       Bale       RidgeCV     0.853973  -439.415685
# 3       Bale         Lasso     0.998862 -1757.808800
# 0      Banwa  RandomForest     0.852457    -0.440001
# ..       ...           ...          ...          ...
# 3   Noumbiel         Lasso     0.996710    -4.393773
# 0       Poni  RandomForest     0.820704   -69.984375
# 1       Poni  DecisionTree     1.000000   -12.543810
# 2       Poni       RidgeCV     0.813992  -132.734672
# 3       Poni         Lasso     0.977131  -212.253758
#
# [180 rows x 4 columns]

# %%
ok.to_csv('sorgho_01.csv')

# %%
#mrr=ok.loc[ok['model'].isin(['DecisionTree'])]
pd.DataFrame(ok[ok['score_test'] >= 0.1 ])
# Out:
#     provinces         model  Score_train  score_test
# 1      Sourou  DecisionTree     1.000000    0.206576
# 2      Leraba       RidgeCV     0.847935    0.250826
# 0     Boulgou  RandomForest     0.845905    0.338670
# 2     Boulgou       RidgeCV     0.999971    0.627069
# 3     Boulgou         Lasso     0.989189    0.270109
# 0  Koulpelogo  RandomForest     0.774250    0.171903
# 2  Koulpelogo       RidgeCV     0.691811    0.101626
# 1         Bam  DecisionTree     1.000000    1.000000
# 1  Boulkiemde  DecisionTree     0.996781    0.208780
# 1        Ziro  DecisionTree     1.000000    0.159773
# 2        Ziro       RidgeCV     0.994367    0.283990
# 3        Ziro         Lasso     0.995281    0.194574
# 3     Kadiogo         Lasso     0.995751    0.636626
# 2   Kompienga       RidgeCV     0.768595    0.560064
# 3   Kompienga         Lasso     0.993179    0.644605
# 0  Kenedougou  RandomForest     0.803389    0.253636
# 1  Kenedougou  DecisionTree     0.999908    0.697221
# ...

# %%
for i in range(1,6):
    ok=Data(df,vect,i,'mais')
    print(len(pd.DataFrame(ok[ok['score_test'] >= 0.1 ])))
# Out:
# 36
# 39
# 34
# 42
# 24
