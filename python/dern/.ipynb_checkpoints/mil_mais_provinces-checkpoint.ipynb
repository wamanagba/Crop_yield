# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import RidgeCV,LassoCV,Lasso
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
data=df=pd.read_csv("C:\\Users\\Yacou\\Desktop\\Yacouba_New\\climte\\Data\\Rendements\\okay\\mil_mais.csv")

# %%
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']

# %%
col=data.columns
col
# Out:
# Index(['provinces', 'year', 'Tmin_ERA5', 'ERA5_Pressure', 'ERA5_Tmax',
#        'ERA5_soil_moisture', 'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
#        'Best_Temp', 'NDVI', 'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
#        'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
#        'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino', 'AMM',
#        'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst', 'qbo', 'sahel_rainfal',
#        'tna', 'tsa', 'mais', 'mil'],
#       dtype='object')

# %%
c0=['provinces']
c1=['year', 'Tmin_ERA5', 'ERA5_Pressure',
        'ERA5_wins', 'ARC2_year', 'Best_Temp_Max',
       'Best_Temp',  'Tamsat_Prec', 'chirps_Prec', 'CDD', 'CWD',
       'PRCPTOT', 'R10mm', 'R1mm', 'R20mm', 'R5mm', 'R95pTOT', 'R99pTOT',
       'RX1day', 'RX5day', 'SDII', 'TNn', 'TXn', 'TNx', 'TXx', 'Nino','sahel_rainfal','qbo' ]
c2=['NDVI','ERA5_soil_moisture','AMM',
       'AMO', 'AO', 'EA', 'NAO', 'NTA', 'PDO', 'gmsst',
       'tna', 'tsa']
d2=data[c2]
d3=data[ 'mil']
d4=data['mais']

# %%
ind1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal',
       'NAO','gmsst', 'R99pTOT', 'PDO', 'qbo', 'AMO','NTA', 'AO','mil','mais']

c1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal']

c2=['NAO','gmsst', 'R99pTOT', 'PDO', 'qbo', 'AMO','NTA', 'AO']

# %%
dt=df.loc[df['provinces'].isin(['Kadiogo'])]

# %%
def model(df,n,crop):
    
    c1=['chirps_Prec', 'ERA5_Pressure', 
       'ERA5_soil_moisture', 'Best_Temp_Max', 'PRCPTOT',
       'Tmin_ERA5', 'TXx', 'R10mm', 'TNx', 'R5mm', 'R1mm',
       'TNn', 'TXn', 'ERA5_wins', 'R20mm', 'RX1day', 'SDII', 'RX5day',
       'R95pTOT', 'CWD', 'year', 'EA', 'CDD', 'Nino', 'sahel_rainfal','R99pTOT']
    d1=dt[c1]
    c2=['NAO','gmsst','PDO', 'qbo', 'AMO','NTA', 'AO']
    d2=dt[c2]
    d2=d2.reset_index(drop=True)
    y = df[crop]
    
    d1 = pd.DataFrame(StandardScaler().fit_transform(d1))
    X=pd.concat([d1,d2],axis=1)
    
    y=pd.array(y)
    y=pd.DataFrame(y)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.17,random_state=n)


    model1 = RidgeCV()
    model2 = Lasso(normalize=True, tol=1e-3)
    model3 = RandomForestRegressor(n_estimators = 2000,max_depth=23)
    model4 = DecisionTreeRegressor(max_depth=5) 

    model1.fit(X_train, y_train.values.ravel())
    model2.fit(X_train, y_train.values.ravel())
    model3.fit(X_train, y_train.values.ravel())
    model4.fit(X_train, y_train.values.ravel())

    train_RidgeCV=model1.score(X_train, y_train)
    test_RidgeCV=model1.score(X_test, y_test)

    train_LassoCV=model2.score(X_train, y_train)
    test_LassoCV=model2.score(X_test, y_test)

    train_RandomForest=model3.score(X_train, y_train)
    test_RandomForest=model3.score(X_test, y_test)

    train_DecisionTree=model4.score(X_train, y_train)
    test_DecisionTree=model4.score(X_test, y_test)


    data = {'model': ['RandomForest', 'DecisionTree', 'RidgeCV', 'Lasso'],
        'Score_train': [train_RandomForest, train_DecisionTree, train_RidgeCV, train_LassoCV],
        'score_test': [test_RandomForest, test_DecisionTree, test_RidgeCV, test_LassoCV]
        }

   # data = {'model': ['RandomForest', 'DecisionTree'],
     #   'Score_train': [train_RandomForest, train_DecisionTree],
     #   'score_test': [test_RandomForest, test_DecisionTree]
     #   }

    d = pd.DataFrame(data)
    return d

# %%
d=dt.loc[dt['provinces'].isin(['Kadiogo'])]
model(d,2,'mais')
# Out:
#           model  Score_train  score_test
# 0  RandomForest     0.889419    0.565886
# 1  DecisionTree     0.999818    0.516748
# 2       RidgeCV     0.872014    0.876824
# 3         Lasso     0.999432    0.966730

# %%
def model_province(dt,prov,n,crop):
    m=prov
    m=np.repeat(m,4, axis=0)
    m={'provinces':m}
    m=pd.DataFrame(m)
    d=dt.loc[dt['provinces'].isin([prov])] #(X, y,test_size=0.17,random_state=3)
    m=pd.concat([m,model(d,n,crop)],axis = 1)
    return m

# %%
model_province(df,'Kadiogo',4,'mais')
# Out:
#   provinces         model  Score_train  score_test
# 0   Kadiogo  RandomForest     0.906142    0.773590
# 1   Kadiogo  DecisionTree     1.000000    0.595203
# 2   Kadiogo       RidgeCV     0.908822    0.636641
# 3   Kadiogo         Lasso     0.999384    0.888347

# %%
def Data(data,v,n,crop):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        P=v[i]
        D=pd.concat([D,model_province(data,P,n,crop)],axis = 0)
    return D

# %%
ok=Data(df,vect,2,'mil')
ok
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2791.5706493152575, tolerance: 1967.0748702974586
#   model = cd_fast.enet_coordinate_descent(
#    provinces         model  Score_train  score_test
# 0       Bale  RandomForest     0.877656   -1.757282
# 1       Bale  DecisionTree     1.000000   -6.781256
# 2       Bale       RidgeCV     0.822892   -2.853112
# 3       Bale         Lasso     0.991046    0.199561
# 0      Banwa  RandomForest     0.808669   -0.107302
# ..       ...           ...          ...         ...
# 3   Noumbiel         Lasso     0.996650   -4.865517
# 0       Poni  RandomForest     0.835472   -4.865293
# 1       Poni  DecisionTree     1.000000   -0.370075
# 2       Poni       RidgeCV     0.659417    0.089606
# 3       Poni         Lasso     0.995215   -0.558559
#
# [180 rows x 4 columns]

# %%
ok.to_csv('Mil_02.csv')

# %%
#mrr=ok.loc[ok['model'].isin(['DecisionTree'])]
pd.DataFrame(ok[ok['score_test'] >= 0.1 ])
# Out:
#     provinces         model  Score_train  score_test
# 0        Bale  RandomForest     0.862650    0.411211
# 2        Bale       RidgeCV     0.819850    0.171355
# 1     Boulgou  DecisionTree     1.000000    0.199560
# 2     Boulgou       RidgeCV     0.753306    0.304655
# 0  Kouritenga  RandomForest     0.846678    0.210982
# 2  Kouritenga       RidgeCV     0.729244    0.431067
# 3  Namentenga         Lasso     0.993486    0.368424
# 0  Boulkiemde  RandomForest     0.870125    0.523954
# 0     Sanguie  RandomForest     0.892628    0.760381
# 1     Sanguie  DecisionTree     1.000000    0.241299
# 0      Bazega  RandomForest     0.826541    0.134871
# 2      Bazega       RidgeCV     0.991871    0.476700
# 3      Bazega         Lasso     0.991041    0.605666
# 0  Zoundweogo  RandomForest     0.870962    0.626539
# 1  Zoundweogo  DecisionTree     1.000000    0.213338
# 2  Zoundweogo       RidgeCV     0.819291    0.209678
# 3  Zoundweogo         Lasso     0.997347    0.715828
# 0     Kadiogo  RandomForest     0.889812    0.576118
# 1     Kadiogo  DecisionTree     1.000000    0.607443
# 2     Kadiogo       RidgeCV     0.872014    0.876824
# 3     Kadiogo         Lasso     0.999432    0.966730
# 0      Gourma  RandomForest     0.814508    0.336597
# 2      Gourma       RidgeCV     0.739760    0.428133
# 3      Gourma         Lasso     0.993750    0.769487
# 0   Kompienga  RandomForest     0.833086    0.757859
# 0         Tuy  RandomForest     0.904621    0.421381
# 1         Tuy  DecisionTree     1.000000    0.230025
# 2         Tuy       RidgeCV     0.999974    0.360040
# 3         Tuy         Lasso     0.998351    0.382237
# 0  Ganzourgou  RandomForest     0.865777    0.399754
# 1  Ganzourgou  DecisionTree     1.000000    0.434902
# 2  Ganzourgou       RidgeCV     0.999967    0.311460
# 3  Ganzourgou         Lasso     0.997422    0.584635
# 2        Ioba       RidgeCV     0.852425    0.268744
# 3        Ioba         Lasso     0.993947    0.668711
# 0        Poni  RandomForest     0.846078    0.563736
# 1        Poni  DecisionTree     1.000000    0.276413
# 2        Poni       RidgeCV     0.864416    0.327417
# 3        Poni         Lasso     0.995951    0.628374

# %%
for i in range(1,6):
    ok=Data(df,vect,i,'mais')
    print(len(pd.DataFrame(ok[ok['score_test'] >= 0.1 ])))
# Out:
# 36
# 39
# 34
# 42
# 24
