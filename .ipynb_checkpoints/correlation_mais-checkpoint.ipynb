# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt

# %%
df=data = pd.read_csv('Mais_D1.csv')
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']
len(vect)
# Out:
# 45

# %%
y=df['year']

# %%
y=df.loc[df['province'].isin(['Bougouriba'])]['year']
# Out:
# 5      2000
# 48     2001
# 94     2002
# 139    2003
# 184    2004
# 229    2005
# 274    2006
# 319    2007
# 364    2008
# 409    2009
# 454    2010
# 499    2011
# 544    2012
# 589    2013
# 634    2014
# 679    2015
# 724    2016
# Name: year, dtype: int64

# %%
def correlation(df,level):
    dt=df.loc[df['province'].isin([level])]
    X = dt.iloc[:, 1:40]
    #y = dt.iloc[:, 37]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI',36:'Mais_area',37:'Nino34',38:'Mais'})
    #a= pd.DataFrame(pd.DataFrame(dt.corrwith(y, axis = 0)).iloc[:,0])

    a=pd.DataFrame(pd.DataFrame(X.corr()).iloc[:,38])
    a.columns=[level]
    return a

# %%
#c=correlation(df,'Banwa')
#c

# %%
def sort_corr(df,level):
    c=correlation(df,level)
    #c= c.sort_values(by=['Bougouriba'])
    absolute=c[level].abs()

    b=pd.DataFrame(absolute).sort_values(by=[level],ascending=False)
    df2 = pd.merge(b, c, left_index=True, right_index=True)
    return df2

# %%
sort_corr(df,'Banwa')
# Out:
#                      Banwa_x   Banwa_y
# Mais                1.000000  1.000000
# EA                  0.372783 -0.372783
# CWD                 0.347595 -0.347595
# AMO_sst             0.334784  0.334784
# Driver.NTA          0.327767  0.327767
# Driver.TNA          0.319441  0.319441
# sahel_rainfall      0.296958  0.296958
# CDD                 0.267643 -0.267643
# R1mm                0.255055  0.255055
# driver.TSA          0.241124  0.241124
# AMM_sst             0.213385  0.213385
# chirps_Prec         0.174053  0.174053
# R95pTOT             0.155475 -0.155475
# NDVI                0.154654  0.154654
# year                0.135099  0.135099
# TXn                 0.120541 -0.120541
# Chirts_Tmin_Temp    0.116864  0.116864
# RX1day              0.112048  0.112048
# SDII                0.108006 -0.108006
# R99pTOT             0.105076 -0.105076
# ERA5_wins           0.094433  0.094433
# TNx                 0.091555 -0.091555
# Chirts_Tmax_Temp    0.086231 -0.086231
# RX5day              0.072729  0.072729
# TNn                 0.072539 -0.072539
# PDO                 0.066234  0.066234
# Nino34              0.064751 -0.064751
# ERA5_Pressure       0.058417  0.058417
# NAO                 0.057117 -0.057117
# gmsst               0.052733 -0.052733
# QBO                 0.047607  0.047607
# Driver.AO           0.046528 -0.046528
# ERA5_soil_moisture  0.031854 -0.031854
# R20mm               0.030180 -0.030180
# R5mm                0.027666  0.027666
# TXx                 0.027481 -0.027481
# R10mm               0.019473  0.019473
# Mais_area           0.009407 -0.009407
# PRCPTOT             0.003276  0.003276

# %%
def table(df,v):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        D=pd.concat([D,correlation(df,v[i])],axis = 1)
    return D

# %%
table(df,vect).to_csv('correlation.csv')

# %%
#table(df,vect).iloc[:,1:20]

# %%
aa=table(df, vect)

# %%
aa['Banwa'].plot()
# Out:
# <AxesSubplot:>

# %%
def figures(df,level):
    dt=df.loc[df['province'].isin([level])]
    X = dt.iloc[:, 1:40]
    #y = dt.iloc[:, 37]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI',36:'Mais_area',37:'Nino34',38:'Mais'})
    #a= pd.DataFrame(pd.DataFrame(dt.corrwith(y, axis = 0)).iloc[:,0])
    PRCPTOT=X['PRCPTOT']
    mais=X['Mais']
    plt.plot(y, PRCPTOT, color='r', label='PRCPTOT')
    plt.plot(y, mais, color='g', label='mais')
    plt.title(level)
    plt.legend()

# %%
figure, axis = plt.subplots(2, 2)
figure(df,'Banwa')
figure(df,'Banwa')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-a91dee11fe89> in <module>
#       1 figure, axis = plt.subplots(2, 2)
# ----> 2 figure(df,'Banwa')
#       3 figure(df,'Banwa')
#       4 plt.show()
#
# TypeError: 'Figure' object is not callable

# %%
X['PRCPTOT']
# Out:
# 0    -2.365235
# 1    -0.638033
# 2    -0.638694
# 3    -0.349678
# 4    -0.291438
# 5     0.601794
# 6    -0.933097
# 7    -0.325428
# 8    -0.091542
# 9     1.112438
# 10    0.067431
# 11   -0.881331
# 12    1.869199
# 13    0.027015
# 14    0.225485
# 15    1.127958
# 16    1.483155
# Name: PRCPTOT, dtype: float64

# %%
    dt=df.loc[df['province'].isin(['Kadiogo'])]
    X = dt.iloc[:, 1:38]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    y = dt.iloc[:, 36]
    X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI',36:'Sorgh0'})
    X=pd.DataFrame(X)
    a=pd.DataFrame(pd.DataFrame(X.corr()).iloc[:,36])
    a.columns=['Sissili']
    a
# Out:
#                      Sissili
# year                0.277167
# driver.TSA         -0.234917
# Driver.TNA          0.374834
# sahel_rainfall      0.440296
# QBO                -0.370935
# NAO                -0.297762
# gmsst               0.304412
# EA                 -0.582084
# AMM_sst             0.380830
# Driver.NTA          0.418869
# AMO_sst             0.329522
# Driver.AO          -0.287181
# PDO                 0.132951
# PRCPTOT             0.470003
# R10mm               0.568680
# R1mm                0.135516
# R20mm               0.247805
# R5mm                0.185548
# R95pTOT             0.669732
# R99pTOT             0.125169
# RX1day              0.262480
# RX5day              0.150911
# SDII                0.419936
# CWD                 0.040972
# CDD                -0.197064
# TNn                 0.105113
# TNx                -0.364380
# TXx                 0.039026
# TXn                -0.403119
# Chirts_Tmax_Temp   -0.320154
# Chirts_Tmin_Temp   -0.136789
# ERA5_Pressure       0.351781
# ERA5_wins           0.342143
# chirps_Prec         0.469213
# ERA5_soil_moisture  0.182323
# NDVI                0.044247
# Sorgh0              1.000000

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X = dt.iloc[:, 1:38]
y = X.iloc[:, 36]
X.corrwith(y, axis = 0)
# Out:
# year                  0.126296
# driver.TSA            0.160893
# Driver.TNA           -0.147845
# sahel_rainfall       -0.277732
# QBO                   0.314169
# NAO                   0.072941
# gmsst                -0.121874
# EA                   -0.129789
# AMM_sst              -0.207266
# Driver.NTA           -0.153189
# AMO_sst               0.020600
# Driver.AO             0.244880
# PDO                  -0.075652
# PRCPTOT               0.026850
# R10mm                -0.129425
# R1mm                 -0.003476
# R20mm                -0.071259
# R5mm                  0.358099
# R95pTOT              -0.218236
# R99pTOT               0.208239
# RX1day                0.062826
# RX5day                0.032505
# SDII                  0.041037
# CWD                  -0.155332
# CDD                  -0.352084
# TNn                   0.069980
# TNx                  -0.083549
# TXx                  -0.095326
# TXn                  -0.000582
# Chirts_Tmax_Temp      0.178621
# Chirts_Tmin_Temp      0.099838
# ERA5_Pressure        -0.168275
# ERA5_wins             0.051990
# chirps_Prec          -0.202112
# ERA5_soil_moisture   -0.131625
# NDVI                  0.059079
# sorgho                1.000000
# dtype: float64

# %%
b=pd.DataFrame()

# %%
dt=df.loc[df['province'].isin(['Nayala'])]
y = dt.iloc[:, 37]
a= pd.DataFrame(pd.DataFrame(dt.corrwith(y, axis = 0)).iloc[:,0])
a.columns=['Nayala']
# Out:
#                       Nayala
# year                0.018158
# driver.TSA          0.125947
# Driver.TNA         -0.012952
# sahel_rainfall      0.176630
# QBO                -0.361031
# NAO                -0.068691
# gmsst               0.172129
# EA                  0.050390
# AMM_sst             0.028437
# Driver.NTA         -0.007770
# AMO_sst            -0.139565
# Driver.AO          -0.000295
# PDO                -0.272469
# PRCPTOT             0.369328
# R10mm               0.367185
# R1mm                0.192304
# R20mm               0.620565
# R5mm               -0.211874
# R95pTOT             0.332188
# R99pTOT             0.336509
# RX1day              0.235218
# RX5day              0.250496
# SDII                0.415076
# CWD                 0.033959
# CDD                -0.203435
# TNn                 0.038129
# TNx                -0.415740
# TXx                -0.134350
# TXn                -0.304910
# Chirts_Tmax_Temp   -0.504999
# Chirts_Tmin_Temp   -0.289520
# ERA5_Pressure       0.089583
# ERA5_wins          -0.355811
# chirps_Prec         0.495837
# ERA5_soil_moisture  0.176743
# NDVI                0.005393
# sorgho              1.000000
