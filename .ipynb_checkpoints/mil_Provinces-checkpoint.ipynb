# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import RidgeCV,LassoCV,Lasso
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %%
df=data = pd.read_csv('data_mais.csv')

# %%
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']

# %%
dt=df.loc[df['province'].isin(['Ganzourgou'])]

# %%
X = dt.iloc[:, 1:38]
y = dt.iloc[:, 38]
X = pd.DataFrame(StandardScaler().fit_transform(X))
y=pd.array(y)
y=pd.DataFrame(y)

# %%
X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI', 36:'Mais_area'})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=3)

# %%
model3 = RandomForestRegressor(n_estimators = 1500,max_depth=23)
model4 = DecisionTreeRegressor(max_depth=80) 
model1 = RidgeCV()
model2= Lasso(normalize=True, tol=1e-3)
model1.fit(X_train, y_train.values.ravel())
model3.fit(X_train, y_train.values.ravel())
model4.fit(X_train, y_train.values.ravel())
model2.fit(X_train, y_train.values.ravel())
# Out:
# Lasso(normalize=True, tol=0.001)

# %%
print(f'model score on RidgeCV: {model1.score(X_test, y_test)}')
print(f'model score on RandomForestRegressor: {model3.score(X_test, y_test)}')
print(f'model score on DecisionTreeRegressor: {model4.score(X_test, y_test)}')
print(f'model score on Lasso: {model2.score(X_test, y_test)}')
# Out:
# model score on RidgeCV: 0.0600731889565268
# model score on RandomForestRegressor: -0.42042754944323146
# model score on DecisionTreeRegressor: -0.997413682538612
# model score on Lasso: 0.7471601291958292

# %%
def model(df,n):
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
    from sklearn.model_selection import train_test_split

    #df.reset_index(inplace = True)
    #df.pop('index')

    X = df.iloc[:, 1:38]
    y = df.iloc[:, 38]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    y=pd.array(y)
    y=pd.DataFrame(y)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.17,random_state=n)


    model1 = RidgeCV()
    model2 = Lasso(normalize=True, tol=1e-3)
    model3 = RandomForestRegressor(n_estimators = 1500,max_depth=23)
    model4 = DecisionTreeRegressor(max_depth=80) 

    model1.fit(X_train, y_train.values.ravel())
    model2.fit(X_train, y_train.values.ravel())
    model3.fit(X_train, y_train.values.ravel())
    model4.fit(X_train, y_train.values.ravel())

    train_RidgeCV=model1.score(X_train, y_train)
    test_RidgeCV=model1.score(X_test, y_test)

    train_LassoCV=model2.score(X_train, y_train)
    test_LassoCV=model2.score(X_test, y_test)

    train_RandomForest=model3.score(X_train, y_train)
    test_RandomForest=model3.score(X_test, y_test)

    train_DecisionTree=model4.score(X_train, y_train)
    test_DecisionTree=model4.score(X_test, y_test)


    data = {'model': ['RandomForest', 'DecisionTree', 'RidgeCV', 'Lasso'],
        'Score_train': [train_RandomForest, train_DecisionTree, train_RidgeCV, train_LassoCV],
        'score_test': [test_RandomForest, test_DecisionTree, test_RidgeCV, test_LassoCV]
        }

   # data = {'model': ['RandomForest', 'DecisionTree'],
     #   'Score_train': [train_RandomForest, train_DecisionTree],
     #   'score_test': [test_RandomForest, test_DecisionTree]
     #   }

    d = pd.DataFrame(data)
    return d

# %%
def model_province(dt,prov,n):
    m=prov
    m=np.repeat(m,4, axis=0)
    m={'province':m}
    m=pd.DataFrame(m)
    d=dt.loc[dt['province'].isin([prov])] #(X, y,test_size=0.17,random_state=3)
    m=pd.concat([m,model(d,n)],axis = 1)
    return m

# %%
model_province(df,'Ganzourgou',3)
# Out:
#      province         model  Score_train  score_test
# 0  Ganzourgou  RandomForest     0.869474    0.931412
# 1  Ganzourgou  DecisionTree     1.000000   -0.196020
# 2  Ganzourgou       RidgeCV     0.859309    0.893390
# 3  Ganzourgou         Lasso     0.994435    0.556306

# %%
def Data(data,v,n):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        P=v[i]
        D=pd.concat([D,model_province(data,P,n)],axis = 0)
    return D

# %%
vect[1]
# Out:
# 'Banwa'

# %%
ok=Data(df,vect,2)
#ok

# %%
ok.to_csv('score.csv')

# %%
#mrr=ok.loc[ok['model'].isin(['DecisionTree'])]
ok[ok['score_test'] >= 0.1 ]
# Out:
#      province         model  Score_train  score_test
# 0        Bale  RandomForest     0.876430    0.484705
# 1        Bale  DecisionTree     1.000000    0.987164
# 2        Bale       RidgeCV     0.875370    0.281989
# 3       Kossi         Lasso     0.994507    0.273334
# 0      Leraba  RandomForest     0.852445    0.172124
# 1      Leraba  DecisionTree     1.000000    0.781909
# 1     Boulgou  DecisionTree     1.000000    0.342818
# 2     Boulgou       RidgeCV     0.818541    0.188004
# 3         Bam         Lasso     0.993871    0.214520
# 0  Boulkiemde  RandomForest     0.868090    0.498918
# 1  Boulkiemde  DecisionTree     1.000000    0.719425
# 2  Boulkiemde       RidgeCV     0.839638    0.477932
# 3  Boulkiemde         Lasso     0.988529    0.362642
# 0     Sanguie  RandomForest     0.911161    0.444872
# 1     Sanguie  DecisionTree     1.000000    0.165593
# 2     Sanguie       RidgeCV     0.929505    0.506824
# 3     Sanguie         Lasso     0.996925    0.756886
# 2      Bazega       RidgeCV     0.860976    0.319260
# 0  Zoundweogo  RandomForest     0.852460    0.166349
# 1  Zoundweogo  DecisionTree     1.000000    0.747878
# 2  Zoundweogo       RidgeCV     0.999974    0.542185
# 3  Zoundweogo         Lasso     0.998257    0.704751
# 0     Kadiogo  RandomForest     0.923790    0.943003
# 1     Kadiogo  DecisionTree     1.000000    0.787238
# 2     Kadiogo       RidgeCV     0.935473    0.942742
# 3     Kadiogo         Lasso     0.999515    0.956240
# 0      Gnagna  RandomForest     0.868719    0.571239
# 3      Gourma         Lasso     0.994103    0.209164
# 0   Kompienga  RandomForest     0.834272    0.435400
# 2   Kompienga       RidgeCV     0.840684    0.406967
# 3   Kompienga         Lasso     0.997073    0.688536
# 2       Tapoa       RidgeCV     0.908350    0.653493
# 3       Tapoa         Lasso     0.997802    0.277915
# 0  Kenedougou  RandomForest     0.860563    0.220445
# 2  Kenedougou       RidgeCV     0.999981    0.449777
# 3  Kenedougou         Lasso     0.999125    0.663665
# 0         Tuy  RandomForest     0.887421    0.434780
# 1         Tuy  DecisionTree     1.000000    0.353220
# 2         Tuy       RidgeCV     0.999977    0.317799
# 3         Tuy         Lasso     0.996755    0.158603
# 0  Ganzourgou  RandomForest     0.875741    0.944977
# 2  Ganzourgou       RidgeCV     0.859309    0.893390
# 3  Ganzourgou         Lasso     0.994435    0.556306
# 1   Kourweogo  DecisionTree     1.000000    0.706226
# 0  Oubritenga  RandomForest     0.835123    0.300564
# 1  Oubritenga  DecisionTree     1.000000    0.472625
# 2  Oubritenga       RidgeCV     0.997652    0.157225
# 0        Ioba  RandomForest     0.899671    0.116773
# 2        Ioba       RidgeCV     0.892358    0.578397
# 0        Poni  RandomForest     0.867193    0.281741
# 2        Poni       RidgeCV     0.894687    0.558694
