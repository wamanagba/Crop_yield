# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import RidgeCV,LassoCV,Lasso
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %%
df=data = pd.read_csv('Mil_all.csv')

# %%
vect=['Bale','Banwa','Kossi','Mouhoun',	'Nayala',	'Sourou',	'Comoe'	,
      'Leraba',	'Boulgou',	'Koulpelogo',	'Kouritenga',	'Bam'	,'Namentenga',
      'Sanmatenga',	'Boulkiemde',	'Sanguie'	,'Sissili',	'Ziro',	'Bazega',	'Nahouri',
      'Zoundweogo',	'Kadiogo','Gnagna',	'Gourma',	'Komandjoari',	'Kompienga'	,'Tapoa',
      'Houet'	,'Kenedougou',	'Tuy','Loroum',	'Passore',	'Yatenga',	'Zondoma',	'Ganzourgou',
      'Kourweogo',	'Oubritenga',
      'Oudalan','Seno',	'Soum',	'Yagha','Bougouriba',	'Ioba',	'Noumbiel',	'Poni']

# %%
dt=df.loc[df['province'].isin(['Kadiogo'])]
dt
# Out:
#     province  year  driver.TSA  Driver.TNA  sahel_rainfall        QBO  \
# 34   Kadiogo  2000    0.286667   -0.076667       -1.333333  -1.613333
# 122  Kadiogo  2001    0.403333    0.116667       41.000000 -20.676667
# 214  Kadiogo  2002    0.376667   -0.113333      -74.666667  13.816667
# 293  Kadiogo  2003    0.296667    0.093333       63.666667 -13.300000
# 340  Kadiogo  2004   -0.153333    0.300000        1.333333  11.726667
# 342  Kadiogo  2005   -0.010000    0.913333       61.666667 -14.106667
# 344  Kadiogo  2006    0.320000    0.453333      -22.666667   8.943333
# 345  Kadiogo  2007    0.316667    0.256667      -56.000000 -13.523333
# 347  Kadiogo  2008    0.720000    0.253333       70.000000  10.470000
# 349  Kadiogo  2009    0.633333   -0.163333      -18.666667   1.733333
# 350  Kadiogo  2010    0.716667    1.286667       79.666667 -24.966667
# 352  Kadiogo  2011    0.330000    0.443333      -34.000000   8.210000
# 354  Kadiogo  2012   -0.110000    0.076667       41.000000 -21.850000
# 356  Kadiogo  2013    0.370000    0.496667      -13.666667  11.470000
# 357  Kadiogo  2014    0.393333   -0.106667      133.666667  -3.213333
# 359  Kadiogo  2015    0.400000   -0.076667      -81.000000 -11.510000
# 361  Kadiogo  2016    0.473333    0.363333       64.666667   2.290000
#
#           NAO     gmsst        EA   AMM_sst  ...        TXx        TXn  \
# 34   0.540000  0.626667 -0.110000 -1.900000  ...  37.333879  28.554400
# 122 -0.003333  0.663333  0.456667 -1.390000  ...  36.633571  28.161624
# 214  0.560000  0.773333  0.106667 -3.733333  ...  36.551866  28.156752
# 293 -0.013333  0.736667  0.416667 -1.136667  ...  36.182031  28.466660
# 340  0.250000  0.640000  0.240000  1.613333  ...  36.378452  29.046488
# 342 -0.440000  0.810000 -0.320000  4.650000  ...  36.220312  27.827409
# 344  0.446667  0.666667 -0.953333  0.733333  ...  36.214210  28.238206
y=pd.array(y)
y=pd.DataFrame(y)

# %%
X=X.rename(columns={0:'year', 1:'driver.TSA', 2:'Driver.TNA', 3:'sahel_rainfall', 4:'QBO', 5:'NAO',
       6:'gmsst', 7:'EA', 8:'AMM_sst', 9:'Driver.NTA', 10:'AMO_sst', 11:'Driver.AO', 12:'PDO',
       13:'PRCPTOT', 14:'R10mm', 15:'R1mm', 16:'R20mm', 17:'R5mm', 18:'R95pTOT', 19:'R99pTOT',
       20:'RX1day', 21:'RX5day',22: 'SDII', 23:'CWD', 24:'CDD', 25:'TNn', 26:'TNx', 27:'TXx', 28:'TXn',
       29:'Chirts_Tmax_Temp', 30:'Chirts_Tmin_Temp', 31:'ERA5_Pressure', 32:'ERA5_wins',
       33:'chirps_Prec', 34:'ERA5_soil_moisture', 35:'NDVI'})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=3)

# %%
model3 = RandomForestRegressor(n_estimators = 1500,max_depth=23)
model4 = DecisionTreeRegressor(max_depth=80) 
model1 = RidgeCV()
model2= Lasso(normalize=True, tol=1e-3)
model1.fit(X_train, y_train.values.ravel())
model3.fit(X_train, y_train.values.ravel())
model4.fit(X_train, y_train.values.ravel())
model2.fit(X_train, y_train.values.ravel())
# Out:
# Lasso(normalize=True, tol=0.001)

# %%
print(f'model score on RidgeCV: {model1.score(X_test, y_test)}')
print(f'model score on RandomForestRegressor: {model3.score(X_test, y_test)}')
print(f'model score on DecisionTreeRegressor: {model4.score(X_test, y_test)}')
print(f'model score on Lasso: {model2.score(X_test, y_test)}')
# Out:
# model score on RidgeCV: -2.779864058334326
# model score on RandomForestRegressor: -0.07131088706617694
# model score on DecisionTreeRegressor: -10.591316836448453
# model score on Lasso: -0.07451457493084357

# %%
def model(df,n):
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
    from sklearn.model_selection import train_test_split

    #df.reset_index(inplace = True)
    #df.pop('index')

    X = df.iloc[:, 1:37]
    y = df.iloc[:, 37]
    X = pd.DataFrame(StandardScaler().fit_transform(X))
    y=pd.array(y)
    y=pd.DataFrame(y)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.17,random_state=n)


    model1 = RidgeCV()
    model2 = Lasso(normalize=True, tol=1e-3)
    model3 = RandomForestRegressor(n_estimators = 1500,max_depth=23)
    model4 = DecisionTreeRegressor(max_depth=80) 

    model1.fit(X_train, y_train.values.ravel())
    model2.fit(X_train, y_train.values.ravel())
    model3.fit(X_train, y_train.values.ravel())
    model4.fit(X_train, y_train.values.ravel())

    train_RidgeCV=model1.score(X_train, y_train)
    test_RidgeCV=model1.score(X_test, y_test)

    train_LassoCV=model2.score(X_train, y_train)
    test_LassoCV=model2.score(X_test, y_test)

    train_RandomForest=model3.score(X_train, y_train)
    test_RandomForest=model3.score(X_test, y_test)

    train_DecisionTree=model4.score(X_train, y_train)
    test_DecisionTree=model4.score(X_test, y_test)


    data = {'model': ['RandomForest', 'DecisionTree', 'RidgeCV', 'Lasso'],
        'Score_train': [train_RandomForest, train_DecisionTree, train_RidgeCV, train_LassoCV],
        'score_test': [test_RandomForest, test_DecisionTree, test_RidgeCV, test_LassoCV]
        }

   # data = {'model': ['RandomForest', 'DecisionTree'],
     #   'Score_train': [train_RandomForest, train_DecisionTree],
     #   'score_test': [test_RandomForest, test_DecisionTree]
     #   }

    d = pd.DataFrame(data)
    return d

# %%
def model_province(dt,prov,n):
    m=prov
    m=np.repeat(m,4, axis=0)
    m={'province':m}
    m=pd.DataFrame(m)
    d=dt.loc[dt['province'].isin([prov])] #(X, y,test_size=0.17,random_state=3)
    m=pd.concat([m,model(d,n)],axis = 1)
    return m

# %%
model_province(df,'Ganzourgou',3)
# Out:
#      province         model  Score_train  score_test
# 0  Ganzourgou  RandomForest     0.843002   -4.161423
# 1  Ganzourgou  DecisionTree     1.000000   -2.969085
# 2  Ganzourgou       RidgeCV     0.914763   -4.313198
# 3  Ganzourgou         Lasso     0.988488   -4.926989

# %%
def Data(data,v,n):
    D=pd.DataFrame()
    for i in range(0,len(v)):
        P=v[i]
        D=pd.concat([D,model_province(data,P,n)],axis = 0)
    return D

# %%
vect[1]
# Out:
# 'Banwa'

# %%
ok=Data(df,vect,2)
#ok

# %%
ok.to_csv('score1.csv')

# %%
#mrr=ok.loc[ok['model'].isin(['DecisionTree'])]
ok[ok['score_test'] >= 0.1 ]
# Out:
#      province         model  Score_train  score_test
# 3       Banwa         Lasso     0.914448    0.609721
# 1      Nayala  DecisionTree     1.000000    0.610457
# 2  Sanmatenga       RidgeCV     0.850430    0.260504
# 0  Boulkiemde  RandomForest     0.856606    0.117876
# 2  Boulkiemde       RidgeCV     0.849754    0.146374
# 0     Sanguie  RandomForest     0.872875    0.697167
# 2     Sanguie       RidgeCV     0.890214    0.539918
# 2     Kadiogo       RidgeCV     0.888039    0.726710
# 3     Kadiogo         Lasso     0.979766    0.874813
# 0      Gourma  RandomForest     0.840954    0.181702
# 1       Tapoa  DecisionTree     1.000000    0.270991
# 0  Kenedougou  RandomForest     0.835212    0.403032
# 1  Kenedougou  DecisionTree     1.000000    0.385641
# 0      Loroum  RandomForest     0.831049    0.183528
# 2      Loroum       RidgeCV     0.845551    0.503283
# 2  Ganzourgou       RidgeCV     0.779016    0.143645
# 0  Oubritenga  RandomForest     0.870308    0.577935
# 1  Oubritenga  DecisionTree     1.000000    0.354570
# 2  Oubritenga       RidgeCV     0.895294    0.186727
# 3  Oubritenga         Lasso     0.980938    0.134256
# 2     Oudalan       RidgeCV     0.834571    0.349091
# 1        Seno  DecisionTree     1.000000    0.285513
